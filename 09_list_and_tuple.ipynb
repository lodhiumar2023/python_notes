# %% [markdown]
# # List

# %%
# Data type List

students_name = ["Kashif", "Nasir", "Umair", "Yasir"]   # indexing [0, 1, 2, 3]
print(students_name)

quiz_list = ["Cake", 10, "bottle", "Grapes", 44, 45, 48]    # indexing [0, 1, 2, 3,]
print(len(quiz_list))   # length of list can also check using len() function same as in string. 

# slicing
print(quiz_list[1:5:1])
print(quiz_list[1:3])
print(quiz_list[1::])
print(quiz_list[-1::-1])
# Out:
# ['Kashif', 'Nasir', 'Umair', 'Yasir']
# 7
# [10, 'bottle', 'Grapes', 44]
# [10, 'bottle']
# [10, 'bottle', 'Grapes', 44, 45, 48]
# [48, 45, 44, 'Grapes', 'bottle', 10, 'Cake']

# %%
# list.append() function 

students_name = ["Kashif", "Nasir", "Umair", "Yasir"]   # indexing [0, 1, 2, 3]
students_name.append(["Noor", "Ahmed"]) # added as a one object, not two different values. 
print((students_name))
print((students_name[4]))
# Out:
# ['Kashif', 'Nasir', 'Umair', 'Yasir', ['Noor', 'Ahmed']]
# ['Noor', 'Ahmed']

# %%
# list.extend() function 
students_name = ["Kashif", "Nasir", "Umair", "Yasir"]
students_name.extend(["Noor", "Ahmed"])  # use to add multiple values at once. 
print(students_name)
# Out:
# ['Kashif', 'Nasir', 'Umair', 'Yasir', 'Noor', 'Ahmed']

# %%
# list.sort()
students_name = ["Umair", "Nasir", "Yasir","Kashif"]
students_name.sort()
print(students_name)

# list.sort(reverse=True)
students_name = ["Umair", "Nasir", "Yasir","Kashif"]
students_name.sort(reverse=True)
print(students_name)
# Out:
# ['Kashif', 'Nasir', 'Umair', 'Yasir']
# ['Yasir', 'Umair', 'Nasir', 'Kashif']

# %%
# list.insert(Index, Value)

students_name = ["Umair", "Nasir", "Yasir","Kashif"]
students_name.insert(1,"Muhammad")
print(students_name)
# Out:
# ['Umair', 'Muhammad', 'Nasir', 'Yasir', 'Kashif']

# %%
# list.remove(Fist Occurrence of a element)
list_serial = [1,2,1,3,4,5,6,]
list_serial.remove(1)
print(list_serial)
# Out:
# [2, 1, 3, 4, 5, 6]

# %%
# list.pop(Index)
list_serial = [1,2,1,3,4,5,6,]
list_serial.pop(1)
print(list_serial)
# Out:
# [1, 1, 3, 4, 5, 6]

# %% [markdown]
# # Tuple

# %%
my_tuple = (1, 2, 3, 4)
print(my_tuple)

# slicing method of Tuple and Python are same. 
print(my_tuple[0:2])
# Out:
# (1, 2, 3, 4)
# (1, 2)

# %%
# difference between Tuple and Sting:
# If a sting in round brackets/ parenthesis written after without comma (,), it will considered a string by python.

my_tuple = ("Apple",)
my_string = ("Apple")

print(type(my_tuple ))
print(type(my_string))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# # Practice:

# %%
# Create a list of 5 numbers and print the second element.

number_list = [1, 2, 3, 4, 5]
print(number_list[1])
# Out:
# 2

# %%
# Create a list of 4 fruits and change the third fruit to "Mango".

fruit_list = ["Apple", "Mango", "Banana", "Grapes"]
fruit_list.insert(2, "Kiwi Fruit")
print(fruit_list)
# Out:
# ['Apple', 'Mango', 'Kiwi Fruit', 'Banana', 'Grapes']

# %%
# Take 5 numbers from the user and store them in a list.

number_list = []

number_1 = int(input("Please enter 1st number: "))
number_2 = int(input("Please enter 2nd number: "))
number_3 = int(input("Please enter 3rd number: "))
number_4 = int(input("Please enter 4th number: "))
number_5 = int(input("Please enter 5th number: "))

number_list.append(number_1)
number_list.append(number_2)
number_list.append(number_3)
number_list.append(number_4)
number_list.append(number_5)

print(number_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Write a program to ask the user to enter names of their 3 favorite movies & store them in a list. 

my_list = []

movie_1 = input("Please enter name Movie 1: ")
movie_2 = input("Please enter name Movie 2: ")
movie_3 = input("Please enter name Movie 3: ")

my_list.append(movie_1)
my_list.append(movie_2)
my_list.append(movie_3)

print(my_list)
# Out:
# ['Mission Impossible', 'Blood Sports', 'White Tigger']

# %%
# Create a list of numbers and print the length of the list.

number_list = [1, 2, 3, 4, 5]
print(len(number_list))
# Out:
# 5

# %%
# Create a list and check if a particular number exists in it.

number_list = [1, 2, 3, 4, 5, 1]
print(number_list.count(1))
# Out:
# 2

# %% [markdown]
# 🟡 Intermediate Level
#
# 6️⃣ Create a list of numbers and print the largest and smallest number.
#
# 7️⃣ Create a list of 6 numbers and print only even numbers from the list.
#
# 8️⃣ Take 5 numbers from the user and print their sum.
#
# 9️⃣ Create a list and remove a specific element from it.
#
# 🔟 Reverse a list without using reverse() method.
#
# 🔵 Slightly Challenging
#
# 1️⃣ Check whether a list is a palindrome.
# Example: [1, 2, 3, 2, 1] → Palindrome
#
# 2️⃣ Count how many times a specific element appears in a list.
#
# 3️⃣ Merge two lists into one list.
#
# 4️⃣ Remove duplicate elements from a list.
#
# 5️⃣ Sort a list without using the sort() method.
