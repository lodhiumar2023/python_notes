# %%
# My first program.
print("Hello World") # print() is builtin function to find output.
# Out:
# Hello World

# %%
# print a statement 

print("My name is Umar Hayat Khan Lodhi")
print("I am 40 years old")
print("My name is Umar Hayat Khan Lodhi" , "I am 40 years old") # to print two lines together using comma(,).
# Out:
# My name is Umar Hayat Khan Lodhi
# I am 40 years old
# My name is Umar Hayat Khan Lodhi I am 40 years old

# %%
# print a number or make calculations. 

print(42)
print(30)
print(42+30)
# Out:
# 42
# 30
# 72
