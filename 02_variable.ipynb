# %%
name = "Umar Hayat Khan Lodhi"
age = 40
price = 250.99

print(name)
print(age)
print(price)
print(name, age, price) # different variables can print simultaneously.
# Out:
# Umar Hayat Khan Lodhi
# 40
# 250.99
# Umar Hayat Khan Lodhi 40 250.99

# %%
age = 40
age_2 = age
print(age_2) # A variable value can assign into another variable.
# Out:
# 40
