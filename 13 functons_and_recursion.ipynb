# %%
# Create a function that prints `"Hello World".

def greeting():
    print("Hello World")

greeting() # calling the function
# Out:
# Hello World

# %%
# Create a function that takes a name as a parameter and prints a greeting message.  
# Example Output:
# `Assalam o Alaikum Umar`
