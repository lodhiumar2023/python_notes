# %%
# From integer to string

a = 10
print(type(a))

a = str(a)
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# From string to integer

a = "10"
print(type(a))

a = int(a)
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# From string to float

a = "4.5"
print(type(a))

a = float(a)
print(type(a))
# Out:
# <class 'str'>
# <class 'float'>
